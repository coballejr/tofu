# %%
import numpy as np
from tofu.modules import ToFULayer
import torch
from tofu.config import data_dir, model_dir
from tofu.utils import motion_capture_pd_dim, motion_capture_pad
import os
from scipy.io import loadmat

# %%
# load data
os.chdir(data_dir)
data,labels = loadmat('PD.mat'), loadmat('Label_mocap.mat')
labels = (labels['Label']-1).flatten()
dgms = [dgm[1] for dgm in data['PD']]

# %%
# define model

class MotionClassifier(torch.nn.Module):
    
    def __init__(self,in_dim,lin_dim,n_classes):
        super(MotionClassifier,self).__init__()
        
        
        self.lin1 = torch.nn.Linear(in_dim,lin_dim)
        self.lin2 = torch.nn.Linear(lin_dim,lin_dim)
        self.lin3 = torch.nn.Linear(lin_dim,lin_dim)
        
        self.lin4 = torch.nn.Linear(lin_dim,int(lin_dim/2))
        self.lin5 = torch.nn.Linear(int(lin_dim/2),int(lin_dim/2))
        
        #self.lin6 = torch.nn.Linear(int(lin_dim/2),int(lin_dim/4))
        
        self.logits = torch.nn.Linear(int(lin_dim/2),n_classes)
        
    def forward(self,h_batch):
        
        
        h = self.lin1(h_batch)
        h = torch.nn.functional.silu(h)
        h = self.lin2(h)
        h = torch.nn.functional.silu(h)
        h = self.lin3(h)
        h = torch.nn.functional.silu(h)
        
        h = self.lin4(h)
        h = torch.nn.functional.silu(h)
        h = self.lin5(h)
        h = torch.nn.functional.silu(h)
        
        #h = self.lin6(h)
        #h = torch.nn.functional.silu(h)
        
        h = self.logits(h)
        
        return h

# %%
# build model
dgm_dims = 57
n_dgms,n_feats,device,birth_lims,birth_death,lin_dim,n_classes =  4, 1, torch.device("cuda" if torch.cuda.is_available() else "cpu"), [10,20], True, 256, 5
in_dim = int(n_dgms*dgm_dims)

ToFU_dim = torch.nn.ModuleList([ToFULayer(n_dgms,n_feats,device,birth_lims,birth_death).to(device).float() for d in range(dgm_dims)])
classifier = MotionClassifier(in_dim,lin_dim,n_classes).to(device).float()

opt_tofu, opt_classifier = torch.optim.Adam(ToFU_dim.parameters(),lr = 1e-2), torch.optim.Adam(classifier.parameters(),lr = 1e-2, weight_decay = 1e-3)
criterion = torch.nn.CrossEntropyLoss()

# %%
# train 
n_obs = len(dgms)
train_perc = 0.8
epochs,batch_size = 100,128 

perm = np.random.choice(n_obs,n_obs,replace = False)
shuffled_data, shuffled_labels = [dgms[i] for i in perm], labels[perm]
X_train, y_train, X_val, y_val = shuffled_data[0:int(train_perc*n_obs)], shuffled_labels[0:int(train_perc*n_obs)], shuffled_data[int(train_perc*n_obs):], shuffled_labels[int(train_perc*n_obs):]


for ep in range(epochs):
    perm = np.random.choice(len(X_train),len(X_train),replace = False)
    X_epoch, y_epoch = [X_train[i] for i in perm], y_train[perm]
    correct = 0
    
    for i in range(0,len(X_train),batch_size):
        opt_tofu.zero_grad()
        opt_classifier.zero_grad()
        
        X_batch, y_batch = X_epoch[i:(i+batch_size)], y_epoch[i:(i+batch_size)]
        vectorizations = [ToFU_dim[d](torch.tensor(motion_capture_pad(motion_capture_pd_dim(X_batch,d))).to(device).float()) for d in range(dgm_dims)]
        v_batch = torch.cat(vectorizations,1)
        
        probs = classifier(v_batch)
        loss = criterion(probs,torch.tensor(y_batch).to(device).long())
        
        _, predicted = torch.max(probs.data, 1)
        correct += (predicted == torch.tensor(y_batch).to(device).long()).sum().item()
        
        loss.backward()
        opt_tofu.step()
        opt_classifier.step()
        
    # report accuracies
    train_acc = correct/len(X_train)
    
    # validate
    with torch.no_grad():
        vectorizations_val = [ToFU_dim[d](torch.tensor(motion_capture_pad(motion_capture_pd_dim(X_val,d))).to(device).float()) for d in range(dgm_dims)]
        v_val = torch.cat(vectorizations_val,1)
        outputs_val = classifier(v_val)
    
    _, predicted = torch.max(outputs_val.data, 1)
    total = len(y_val)
    correct = (predicted == torch.tensor(y_val).to(device).long()).sum().item()
    val_acc = correct/total
    print('Epoch ' + str(ep + 1) + ' Training Accuracy: ' + str(train_acc),', Validation Accuracy: ' + str(val_acc))
# Out:
# Epoch 1 Training Accuracy: 0.1349206349206349 , Validation Accuracy: 0.3125
# Epoch 2 Training Accuracy: 0.30158730158730157 , Validation Accuracy: 0.1875
# Epoch 3 Training Accuracy: 0.2698412698412698 , Validation Accuracy: 0.15625
# Epoch 4 Training Accuracy: 0.23809523809523808 , Validation Accuracy: 0.25
# Epoch 5 Training Accuracy: 0.24603174603174602 , Validation Accuracy: 0.21875
# Epoch 6 Training Accuracy: 0.2857142857142857 , Validation Accuracy: 0.5
# Epoch 7 Training Accuracy: 0.38095238095238093 , Validation Accuracy: 0.28125
# Epoch 8 Training Accuracy: 0.30952380952380953 , Validation Accuracy: 0.46875
# Epoch 9 Training Accuracy: 0.42063492063492064 , Validation Accuracy: 0.4375
# Epoch 10 Training Accuracy: 0.42857142857142855 , Validation Accuracy: 0.53125
# Epoch 11 Training Accuracy: 0.49206349206349204 , Validation Accuracy: 0.5625
# Epoch 12 Training Accuracy: 0.5079365079365079 , Validation Accuracy: 0.5625
# Epoch 13 Training Accuracy: 0.5 , Validation Accuracy: 0.5
# Epoch 14 Training Accuracy: 0.47619047619047616 , Validation Accuracy: 0.40625
# Epoch 15 Training Accuracy: 0.40476190476190477 , Validation Accuracy: 0.4375
# Epoch 16 Training Accuracy: 0.4126984126984127 , Validation Accuracy: 0.5625
# Epoch 17 Training Accuracy: 0.5 , Validation Accuracy: 0.5625
# Epoch 18 Training Accuracy: 0.5238095238095238 , Validation Accuracy: 0.53125
# Epoch 19 Training Accuracy: 0.49206349206349204 , Validation Accuracy: 0.59375
# Epoch 20 Training Accuracy: 0.5317460317460317 , Validation Accuracy: 0.53125
# Epoch 21 Training Accuracy: 0.4444444444444444 , Validation Accuracy: 0.53125
# Epoch 22 Training Accuracy: 0.49206349206349204 , Validation Accuracy: 0.53125
# Epoch 23 Training Accuracy: 0.5238095238095238 , Validation Accuracy: 0.59375
# Epoch 24 Training Accuracy: 0.5555555555555556 , Validation Accuracy: 0.53125
# Epoch 25 Training Accuracy: 0.5238095238095238 , Validation Accuracy: 0.53125
# Epoch 26 Training Accuracy: 0.48412698412698413 , Validation Accuracy: 0.625
# Epoch 27 Training Accuracy: 0.5952380952380952 , Validation Accuracy: 0.53125
# Epoch 28 Training Accuracy: 0.5238095238095238 , Validation Accuracy: 0.5625
# Epoch 29 Training Accuracy: 0.5793650793650794 , Validation Accuracy: 0.53125
# Epoch 30 Training Accuracy: 0.5238095238095238 , Validation Accuracy: 0.5625
# Epoch 31 Training Accuracy: 0.5396825396825397 , Validation Accuracy: 0.5625
# Epoch 32 Training Accuracy: 0.5873015873015873 , Validation Accuracy: 0.53125
# Epoch 33 Training Accuracy: 0.5317460317460317 , Validation Accuracy: 0.4375
# Epoch 34 Training Accuracy: 0.48412698412698413 , Validation Accuracy: 0.59375
# Epoch 35 Training Accuracy: 0.6190476190476191 , Validation Accuracy: 0.59375
# Epoch 36 Training Accuracy: 0.626984126984127 , Validation Accuracy: 0.40625
# Epoch 37 Training Accuracy: 0.5634920634920635 , Validation Accuracy: 0.625
# Epoch 38 Training Accuracy: 0.6587301587301587 , Validation Accuracy: 0.5625
# Epoch 39 Training Accuracy: 0.6507936507936508 , Validation Accuracy: 0.5625
# Epoch 40 Training Accuracy: 0.6587301587301587 , Validation Accuracy: 0.53125
# Epoch 41 Training Accuracy: 0.6825396825396826 , Validation Accuracy: 0.5625
# Epoch 42 Training Accuracy: 0.6587301587301587 , Validation Accuracy: 0.59375
# Epoch 43 Training Accuracy: 0.6587301587301587 , Validation Accuracy: 0.59375
# Epoch 44 Training Accuracy: 0.6507936507936508 , Validation Accuracy: 0.625
# Epoch 45 Training Accuracy: 0.6825396825396826 , Validation Accuracy: 0.59375
# Epoch 46 Training Accuracy: 0.6507936507936508 , Validation Accuracy: 0.5625
# Epoch 47 Training Accuracy: 0.6428571428571429 , Validation Accuracy: 0.5
# Epoch 48 Training Accuracy: 0.6507936507936508 , Validation Accuracy: 0.625
# Epoch 49 Training Accuracy: 0.6587301587301587 , Validation Accuracy: 0.53125
# Epoch 50 Training Accuracy: 0.6984126984126984 , Validation Accuracy: 0.65625
# Epoch 51 Training Accuracy: 0.5873015873015873 , Validation Accuracy: 0.59375
# Epoch 52 Training Accuracy: 0.626984126984127 , Validation Accuracy: 0.625
# Epoch 53 Training Accuracy: 0.6507936507936508 , Validation Accuracy: 0.375
# Epoch 54 Training Accuracy: 0.4126984126984127 , Validation Accuracy: 0.4375
# Epoch 55 Training Accuracy: 0.5476190476190477 , Validation Accuracy: 0.5
# Epoch 56 Training Accuracy: 0.5555555555555556 , Validation Accuracy: 0.59375
# Epoch 57 Training Accuracy: 0.5634920634920635 , Validation Accuracy: 0.5625
# Epoch 58 Training Accuracy: 0.6031746031746031 , Validation Accuracy: 0.65625
# Epoch 59 Training Accuracy: 0.6190476190476191 , Validation Accuracy: 0.65625
# Epoch 60 Training Accuracy: 0.6031746031746031 , Validation Accuracy: 0.65625
# Epoch 61 Training Accuracy: 0.6190476190476191 , Validation Accuracy: 0.625
# Epoch 62 Training Accuracy: 0.626984126984127 , Validation Accuracy: 0.65625
# Epoch 63 Training Accuracy: 0.6666666666666666 , Validation Accuracy: 0.625
# Epoch 64 Training Accuracy: 0.626984126984127 , Validation Accuracy: 0.625
# Epoch 65 Training Accuracy: 0.6507936507936508 , Validation Accuracy: 0.65625
# Epoch 66 Training Accuracy: 0.7142857142857143 , Validation Accuracy: 0.59375
# Epoch 67 Training Accuracy: 0.6904761904761905 , Validation Accuracy: 0.625
# Epoch 68 Training Accuracy: 0.6349206349206349 , Validation Accuracy: 0.65625
# Epoch 69 Training Accuracy: 0.746031746031746 , Validation Accuracy: 0.59375
# Epoch 70 Training Accuracy: 0.6984126984126984 , Validation Accuracy: 0.5625
# Epoch 71 Training Accuracy: 0.7301587301587301 , Validation Accuracy: 0.5625
# Epoch 72 Training Accuracy: 0.6904761904761905 , Validation Accuracy: 0.5625
# Epoch 73 Training Accuracy: 0.746031746031746 , Validation Accuracy: 0.5625
# Epoch 74 Training Accuracy: 0.8095238095238095 , Validation Accuracy: 0.625
# Epoch 75 Training Accuracy: 0.7857142857142857 , Validation Accuracy: 0.5625
# Epoch 76 Training Accuracy: 0.746031746031746 , Validation Accuracy: 0.53125
# Epoch 77 Training Accuracy: 0.7063492063492064 , Validation Accuracy: 0.625
# Epoch 78 Training Accuracy: 0.8015873015873016 , Validation Accuracy: 0.625
# Epoch 79 Training Accuracy: 0.7698412698412699 , Validation Accuracy: 0.53125
# Epoch 80 Training Accuracy: 0.6984126984126984 , Validation Accuracy: 0.53125
# Epoch 81 Training Accuracy: 0.6666666666666666 , Validation Accuracy: 0.5625
# Epoch 82 Training Accuracy: 0.7936507936507936 , Validation Accuracy: 0.625
# Epoch 83 Training Accuracy: 0.7698412698412699 , Validation Accuracy: 0.6875
# Epoch 84 Training Accuracy: 0.7936507936507936 , Validation Accuracy: 0.65625
# Epoch 85 Training Accuracy: 0.746031746031746 , Validation Accuracy: 0.6875
# Epoch 86 Training Accuracy: 0.8253968253968254 , Validation Accuracy: 0.65625
# Epoch 87 Training Accuracy: 0.7777777777777778 , Validation Accuracy: 0.65625
# Epoch 88 Training Accuracy: 0.7857142857142857 , Validation Accuracy: 0.71875
# Epoch 89 Training Accuracy: 0.8015873015873016 , Validation Accuracy: 0.65625
# Epoch 90 Training Accuracy: 0.7619047619047619 , Validation Accuracy: 0.71875
# Epoch 91 Training Accuracy: 0.8174603174603174 , Validation Accuracy: 0.5625
# Epoch 92 Training Accuracy: 0.753968253968254 , Validation Accuracy: 0.625
# Epoch 93 Training Accuracy: 0.7301587301587301 , Validation Accuracy: 0.59375
# Epoch 94 Training Accuracy: 0.7698412698412699 , Validation Accuracy: 0.71875
# Epoch 95 Training Accuracy: 0.7936507936507936 , Validation Accuracy: 0.6875
# Epoch 96 Training Accuracy: 0.7936507936507936 , Validation Accuracy: 0.71875
# Epoch 97 Training Accuracy: 0.8492063492063492 , Validation Accuracy: 0.625
# Epoch 98 Training Accuracy: 0.8492063492063492 , Validation Accuracy: 0.65625
# Epoch 99 Training Accuracy: 0.7777777777777778 , Validation Accuracy: 0.71875
# Epoch 100 Training Accuracy: 0.7857142857142857 , Validation Accuracy: 0.53125
